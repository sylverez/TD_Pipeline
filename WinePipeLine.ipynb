# %% [markdown]
# # Pipeline & GridSearch

# %%
#importez les librairies

# %%
#loader le dataset & checker les valeurs manquantes 
    # https://www.kaggle.com/uciml/red-wine-quality-cortez-et-al-2009
# Out:
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# dtype: int64

# %%
#afficher votre dataset
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5

# %%
#afficher la shape du dataset 
2
# Out:
# (1599, 12)

# %%
#defenir votre target et afficher sa shape
# Out:
# (1599, 1)

# %%
#afficher la répartition de la target
# Out:
# 5    681
# 6    638
# 7    199
# 4     53
# 8     18
# 3     10
# Name: quality, dtype: int64

# %%
#afficher la matrice de correlation des features

# %%
#afficher les correlations des variables 
    #pH=f(Fixed Acidity)
    #Residual Sugar=f(Fixed Acidity)
#qu'en pensez vous ?

# %%
#définir nos variables de travail (X et y)

# %%
#créer un pipeline avec deux objets : 
    #un objet "scaler" 
    #un objet "estimator" SVM

# %%
#créer une grille de paramètres pour le pipeline 
    #chercher les deux paramètres sur lesquelles inférer

# %%
#spliter vos variables X_train, X_test, y_train, y_test 
    #attention à bien gérer la répartition de votre target

# %%
#créer un objet gridsearch avec les paramètres définit ci-dessus 
    #instancier un cross validation de 5batch 
    #afficher votre score () ainsi que les meilleurs paramètres avec le temps d'execution
